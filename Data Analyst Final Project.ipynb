# %%
print("The goal for this project was to do the following:")
print("Get acquainted with the data")
print("Clean the data so it is ready for analysis")
print("Develop some questions for analysis")
print("Analyze variables within the data to gain patterns and insights on these questions")
# Out:
# The goal for this project was to do the following:
# Get acquainted with the data
# Clean the data so it is ready for analysis
# Develop some questions for analysis
# Analyze variables within the data to gain patterns and insights on these questions

# %%
# sets up matplotlib with interactive features
# %matplotlib notebook
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
print("Data for this project was downloaded from Kaggle:")
print("https://www.kaggle.com/andrewmvd/heart-failure-clinical-data")
# Out:
# Data for this project was downloaded from Kaggle:
# https://www.kaggle.com/andrewmvd/heart-failure-clinical-data

# %%
data = pd.read_csv("E:\Randy\Documents\GitHub\Data-Analyst-Final-Project\heart_data")
# load and explore
pd.set_option('display.max_columns', None)
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-5-faf6afec12e6> in <module>
# ----> 1 data = pd.read_csv("E:\Randy\Documents\GitHub\Data-Analyst-Final-Project\heart_data")
#       2 # load and explore
#       3 pd.set_option('display.max_columns', None)
#       4 print(data.head())
#
# ...
